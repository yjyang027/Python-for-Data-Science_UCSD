# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %% [markdown]
# **The functions that the OS module** provides allows you to interface with the underlying operating system that Python is running on – be that Windows, Mac or Linux. <br>
# You can find important information about your location or about the process.
#
# **The Pickle module** is serializing and de-serializing a Python object structure:<br>
# In this case, the Twitter object (dict), into **a character stream** so the object can be created later in Python.

# %%
import pickle
import os

# %% [markdown]
# Create a pickle file - secret_twitter_credentials, which will enable you to authenticate with the Twitter API to access the data.

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = 'qC5eGQtluR6KC552C2OxXgbEl'
    Twitter['Consumer Secret'] = 'J2kwUgajrGkK9rtQ3XB8VL2ZskDxMAzK8oObwO2nmRDhDePE6B'
    Twitter['Access Token'] = '488484886-2IpT6dG4vb5tirYY3fuR0BY9C2nyXKnJ7B7uQaaH'
    Twitter['Access Token Secret'] = 'BVHqqJ2qP7oqNY0SihtXa9ZSjXxvapYGGKTV42NS4hxI7'
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# **pickle.dump( )**: <br>
# Write the pickled representation of the object obj (Twitter) to the open file object file (f).<br>
#
# **open( )**:<br>
# You can also open a file in **“rb” (read binary), “w” (write), “a” (append), or “wb” (write binary)**. Note that if you use either “w” or “wb”, Python will overwrite the file, if it exists already or create it if the file doesn’t exist.

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages (1.18.0)

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %% [markdown]
# **OAuth** allows users to grant access to their Twitter accounts for your application without you knowing the passwords.<br>
# Use the authentication and create **twitter_api, a Twitter-Api object** we will use to start accessing the data via the Twitter API.

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])
print (auth)
twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.oauth.OAuth object at 0x10a4f4be0>
# <twitter.api.Twitter object at 0x10a4f4d30>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization (_id):
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID) # Top 50
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
len (world_trends)
# Out:
# 1

# %% [markdown]
# **The API response is in JSON format (like a hierarchical database using Python Dictionary).** <br>
# **JSON (JavaScript Object Notation) is an open-standard file format** for data interchange on the web. JSON is a lightweight **text based, data-interchange format and it completely language independent**. <br>
#
# **[{ 'trends': X,   'as_of': '2019-10-10',   'created_at': '2019-10-10',   'locations': [{'name': 'Worldwide', 'woeid': 1}]  }]<br>**
# **where X = [{'name':  ,'url':  ,'promoted_content':   ,'query':  ,'tweet_volume':   }, {}...]<br>**
# https://developer.twitter.com/en/docs/trends/trends-for-location/api-reference/get-trends-place<br>
#
# JSON can store Lists, bools, numbers, tuples and dictionaries. But to be saved into a file, all these structures must be reduced to strings.

# %%
world_trends[:2]
# Out:
# [{'trends': [{'name': '避難勧告',
#     'url': 'http://twitter.com/search?q=%E9%81%BF%E9%9B%A3%E5%8B%A7%E5%91%8A',
#     'promoted_content': None,
#     'query': '%E9%81%BF%E9%9B%A3%E5%8B%A7%E5%91%8A',
#     'tweet_volume': 212558},
#    {'name': '避難所',
#     'url': 'http://twitter.com/search?q=%E9%81%BF%E9%9B%A3%E6%89%80',
#     'promoted_content': None,
#     'query': '%E9%81%BF%E9%9B%A3%E6%89%80',
#     'tweet_volume': 176175},
#    {'name': '多摩川',
#     'url': 'http://twitter.com/search?q=%E5%A4%9A%E6%91%A9%E5%B7%9D',
#     'promoted_content': None,
#     'query': '%E5%A4%9A%E6%91%A9%E5%B7%9D',
#     'tweet_volume': 89763},
#    {'name': '#PrayForJapan',
#     'url': 'http://twitter.com/search?q=%23PrayForJapan',
#     'promoted_content': None,
#     'query': '%23PrayForJapan',
#     'tweet_volume': 128570},
#    {'name': '避難準備',
#     'url': 'http://twitter.com/search?q=%E9%81%BF%E9%9B%A3%E6%BA%96%E5%82%99',
#     'promoted_content': None,
#     'query': '%E9%81%BF%E9%9B%A3%E6%BA%96%E5%82%99',
#     'tweet_volume': 89031},
#    {'name': '#台風だけど出社させた企業',
#     'url': 'http://twitter.com/search?q=%23%E5%8F%B0%E9%A2%A8%E3%81%A0%E3%81%91%E3%81%A9%E5%87%BA%E7%A4%BE%E3%81%95%E3%81%9B%E3%81%9F%E4%BC%81%E6%A5%AD',
#     'promoted_content': None,
#     'query': '%23%E5%8F%B0%E9%A2%A8%E3%81%A0%E3%81%91%E3%81%A9%E5%87%BA%E7%A4%BE%E3%81%95%E3%81%9B%E3%81%9F%E4%BC%81%E6%A5%AD',
#     'tweet_volume': 75807},
#    {'name': 'Robert Forster',
#     'url': 'http://twitter.com/search?q=%22Robert+Forster%22',
#     'promoted_content': None,
#     'query': '%22Robert+Forster%22',
#     'tweet_volume': 22321},
#    {'name': '警戒レベル4',
#     'url': 'http://twitter.com/search?q=%E8%AD%A6%E6%88%92%E3%83%AC%E3%83%99%E3%83%AB4',
#     'promoted_content': None,
#     'query': '%E8%AD%A6%E6%88%92%E3%83%AC%E3%83%99%E3%83%AB4',
#     'tweet_volume': 47713},
#    {'name': 'Ralf',
#     'url': 'http://twitter.com/search?q=Ralf',
#     'promoted_content': None,
#     'query': 'Ralf',
#     'tweet_volume': 17016},
#    {'name': 'エリアメール',
#     'url': 'http://twitter.com/search?q=%E3%82%A8%E3%83%AA%E3%82%A2%E3%83%A1%E3%83%BC%E3%83%AB',
#     'promoted_content': None,
#     'query': '%E3%82%A8%E3%83%AA%E3%82%A2%E3%83%A1%E3%83%BC%E3%83%AB',
#     'tweet_volume': 22344},
#    {'name': '#BigilTrailerDay',
#     'url': 'http://twitter.com/search?q=%23BigilTrailerDay',
#     'promoted_content': None,
#     'query': '%23BigilTrailerDay',
#     'tweet_volume': 73448},
#    {'name': '緊急速報',
#     'url': 'http://twitter.com/search?q=%E7%B7%8A%E6%80%A5%E9%80%9F%E5%A0%B1',
#     'promoted_content': None,
#     'query': '%E7%B7%8A%E6%80%A5%E9%80%9F%E5%A0%B1',
#     'tweet_volume': 42492},
#    {'name': 'カエサル',
#     'url': 'http://twitter.com/search?q=%E3%82%AB%E3%82%A8%E3%82%B5%E3%83%AB',
#     'promoted_content': None,
#     'query': '%E3%82%AB%E3%82%A8%E3%82%B5%E3%83%AB',
#     'tweet_volume': 18722},
#    {'name': 'Anibal Sanchez',
#     'url': 'http://twitter.com/search?q=%22Anibal+Sanchez%22',
#     'promoted_content': None,
#     'query': '%22Anibal+Sanchez%22',
#     'tweet_volume': 15879},
#    {'name': '避難場所',
#     'url': 'http://twitter.com/search?q=%E9%81%BF%E9%9B%A3%E5%A0%B4%E6%89%80',
#     'promoted_content': None,
#     'query': '%E9%81%BF%E9%9B%A3%E5%A0%B4%E6%89%80',
#     'tweet_volume': 74496},
#    {'name': '#台風19',
#     'url': 'http://twitter.com/search?q=%23%E5%8F%B0%E9%A2%A819',
#     'promoted_content': None,
#     'query': '%23%E5%8F%B0%E9%A2%A819',
#     'tweet_volume': 298385},
#    {'name': '暴風域',
#     'url': 'http://twitter.com/search?q=%E6%9A%B4%E9%A2%A8%E5%9F%9F',
#     'promoted_content': None,
#     'query': '%E6%9A%B4%E9%A2%A8%E5%9F%9F',
#     'tweet_volume': 86907},
#    {'name': '避難指示',
#     'url': 'http://twitter.com/search?q=%E9%81%BF%E9%9B%A3%E6%8C%87%E7%A4%BA',
#     'promoted_content': None,
#     'query': '%E9%81%BF%E9%9B%A3%E6%8C%87%E7%A4%BA',
#     'tweet_volume': 25864},
#    {'name': '#ShaneXJeffree',
#     'url': 'http://twitter.com/search?q=%23ShaneXJeffree',
#     'promoted_content': None,
#     'query': '%23ShaneXJeffree',
#     'tweet_volume': 27380},
#    {'name': 'うんこ10連ガチャ',
#     'url': 'http://twitter.com/search?q=%E3%81%86%E3%82%93%E3%81%9310%E9%80%A3%E3%82%AC%E3%83%81%E3%83%A3',
#     'promoted_content': None,
#     'query': '%E3%81%86%E3%82%93%E3%81%9310%E9%80%A3%E3%82%AC%E3%83%81%E3%83%A3',
#     'tweet_volume': None},
#    {'name': 'Bayley',
#     'url': 'http://twitter.com/search?q=Bayley',
#     'promoted_content': None,
#     'query': 'Bayley',
#     'tweet_volume': 31317},
#    {'name': 'ピーク',
#     'url': 'http://twitter.com/search?q=%E3%83%94%E3%83%BC%E3%82%AF',
#     'promoted_content': None,
#     'query': '%E3%83%94%E3%83%BC%E3%82%AF',
#     'tweet_volume': 40061},
#    {'name': 'ほん怖',
#     'url': 'http://twitter.com/search?q=%E3%81%BB%E3%82%93%E6%80%96',
#     'promoted_content': None,
#     'query': '%E3%81%BB%E3%82%93%E6%80%96',
#     'tweet_volume': 28774},
#    {'name': 'ハイキュー',
#     'url': 'http://twitter.com/search?q=%E3%83%8F%E3%82%A4%E3%82%AD%E3%83%A5%E3%83%BC',
#     'promoted_content': None,
#     'query': '%E3%83%8F%E3%82%A4%E3%82%AD%E3%83%A5%E3%83%BC',
#     'tweet_volume': 32994},
#    {'name': '江戸川区',
#     'url': 'http://twitter.com/search?q=%E6%B1%9F%E6%88%B8%E5%B7%9D%E5%8C%BA',
#     'promoted_content': None,
#     'query': '%E6%B1%9F%E6%88%B8%E5%B7%9D%E5%8C%BA',
#     'tweet_volume': 65902},
#    {'name': '雨と風',
#     'url': 'http://twitter.com/search?q=%E9%9B%A8%E3%81%A8%E9%A2%A8',
#     'promoted_content': None,
#     'query': '%E9%9B%A8%E3%81%A8%E9%A2%A8',
#     'tweet_volume': 76433},
#    {'name': 'Chocked',
#     'url': 'http://twitter.com/search?q=Chocked',
#     'promoted_content': None,
#     'query': 'Chocked',
#     'tweet_volume': 10769},
#    {'name': '氾濫危険水位',
#     'url': 'http://twitter.com/search?q=%E6%B0%BE%E6%BF%AB%E5%8D%B1%E9%99%BA%E6%B0%B4%E4%BD%8D',
#     'promoted_content': None,
#     'query': '%E6%B0%BE%E6%BF%AB%E5%8D%B1%E9%99%BA%E6%B0%B4%E4%BD%8D',
#     'tweet_volume': 33061},
#    {'name': 'ライブカメラ',
#     'url': 'http://twitter.com/search?q=%E3%83%A9%E3%82%A4%E3%83%96%E3%82%AB%E3%83%A1%E3%83%A9',
#     'promoted_content': None,
#     'query': '%E3%83%A9%E3%82%A4%E3%83%96%E3%82%AB%E3%83%A1%E3%83%A9',
#     'tweet_volume': 19371},
#    {'name': '避難警報',
#     'url': 'http://twitter.com/search?q=%E9%81%BF%E9%9B%A3%E8%AD%A6%E5%A0%B1',
#     'promoted_content': None,
#     'query': '%E9%81%BF%E9%9B%A3%E8%AD%A6%E5%A0%B1',
#     'tweet_volume': 31875},
#    {'name': '無事帰宅',
#     'url': 'http://twitter.com/search?q=%E7%84%A1%E4%BA%8B%E5%B8%B0%E5%AE%85',
#     'promoted_content': None,
#     'query': '%E7%84%A1%E4%BA%8B%E5%B8%B0%E5%AE%85',
#     'tweet_volume': 17516},
#    {'name': 'アナザーディエンド',
#     'url': 'http://twitter.com/search?q=%E3%82%A2%E3%83%8A%E3%82%B6%E3%83%BC%E3%83%87%E3%82%A3%E3%82%A8%E3%83%B3%E3%83%89',
#     'promoted_content': None,
#     'query': '%E3%82%A2%E3%83%8A%E3%82%B6%E3%83%BC%E3%83%87%E3%82%A3%E3%82%A8%E3%83%B3%E3%83%89',
#     'tweet_volume': 18433},
#    {'name': 'プロミ',
#     'url': 'http://twitter.com/search?q=%E3%83%97%E3%83%AD%E3%83%9F',
#     'promoted_content': None,
#     'query': '%E3%83%97%E3%83%AD%E3%83%9F',
#     'tweet_volume': None},
#    {'name': 'Ryan Zimmerman',
#     'url': 'http://twitter.com/search?q=%22Ryan+Zimmerman%22',
#     'promoted_content': None,
#     'query': '%22Ryan+Zimmerman%22',
#     'tweet_volume': None},
#    {'name': '雨漏り',
#     'url': 'http://twitter.com/search?q=%E9%9B%A8%E6%BC%8F%E3%82%8A',
#     'promoted_content': None,
#     'query': '%E9%9B%A8%E6%BC%8F%E3%82%8A',
#     'tweet_volume': 11811},
#    {'name': 'Juanfer',
#     'url': 'http://twitter.com/search?q=Juanfer',
#     'promoted_content': None,
#     'query': 'Juanfer',
#     'tweet_volume': 31875},
#    {'name': '#PVLCollegiateConference2019',
#     'url': 'http://twitter.com/search?q=%23PVLCollegiateConference2019',
#     'promoted_content': None,
#     'query': '%23PVLCollegiateConference2019',
#     'tweet_volume': None},
#    {'name': '#اليوم_العالمي_للرسايل',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D9%8A%D9%88%D9%85_%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85%D9%8A_%D9%84%D9%84%D8%B1%D8%B3%D8%A7%D9%8A%D9%84',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D9%8A%D9%88%D9%85_%D8%A7%D9%84%D8%B9%D8%A7%D9%84%D9%85%D9%8A_%D9%84%D9%84%D8%B1%D8%B3%D8%A7%D9%8A%D9%84',
#     'tweet_volume': 25267},
#    {'name': '#台風怖すぎるから会いたい人たち',
#     'url': 'http://twitter.com/search?q=%23%E5%8F%B0%E9%A2%A8%E6%80%96%E3%81%99%E3%81%8E%E3%82%8B%E3%81%8B%E3%82%89%E4%BC%9A%E3%81%84%E3%81%9F%E3%81%84%E4%BA%BA%E3%81%9F%E3%81%A1',
#     'promoted_content': None,
#     'query': '%23%E5%8F%B0%E9%A2%A8%E6%80%96%E3%81%99%E3%81%8E%E3%82%8B%E3%81%8B%E3%82%89%E4%BC%9A%E3%81%84%E3%81%9F%E3%81%84%E4%BA%BA%E3%81%9F%E3%81%A1',
#     'tweet_volume': 14453},
#    {'name': '#WWEDraft',
#     'url': 'http://twitter.com/search?q=%23WWEDraft',
#     'promoted_content': None,
#     'query': '%23WWEDraft',
#     'tweet_volume': 45828},
#    {'name': '#TeamNeilEnPremiosTelehit',
#     'url': 'http://twitter.com/search?q=%23TeamNeilEnPremiosTelehit',
#     'promoted_content': None,
#     'query': '%23TeamNeilEnPremiosTelehit',
#     'tweet_volume': None},
#    {'name': '#ProvaDeFogo',
#     'url': 'http://twitter.com/search?q=%23ProvaDeFogo',
#     'promoted_content': None,
#     'query': '%23ProvaDeFogo',
#     'tweet_volume': 16076},
#    {'name': '#TheReadOnFuse',
#     'url': 'http://twitter.com/search?q=%23TheReadOnFuse',
#     'promoted_content': None,
#     'query': '%23TheReadOnFuse',
#     'tweet_volume': None},
#    {'name': '#激獣神祭',
#     'url': 'http://twitter.com/search?q=%23%E6%BF%80%E7%8D%A3%E7%A5%9E%E7%A5%AD',
#     'promoted_content': None,
#     'query': '%23%E6%BF%80%E7%8D%A3%E7%A5%9E%E7%A5%AD',
#     'tweet_volume': None},
#    {'name': '#cumartesi',
#     'url': 'http://twitter.com/search?q=%23cumartesi',
#     'promoted_content': None,
#     'query': '%23cumartesi',
#     'tweet_volume': None},
#    {'name': '#كلمه_وقولها_للحب',
#     'url': 'http://twitter.com/search?q=%23%D9%83%D9%84%D9%85%D9%87_%D9%88%D9%82%D9%88%D9%84%D9%87%D8%A7_%D9%84%D9%84%D8%AD%D8%A8',
#     'promoted_content': None,
#     'query': '%23%D9%83%D9%84%D9%85%D9%87_%D9%88%D9%82%D9%88%D9%84%D9%87%D8%A7_%D9%84%D9%84%D8%AD%D8%A8',
#     'tweet_volume': 10740},
#    {'name': '#Eliud159',
#     'url': 'http://twitter.com/search?q=%23Eliud159',
#     'promoted_content': None,
#     'query': '%23Eliud159',
#     'tweet_volume': 18724},
#    {'name': '#SaturdayMotivation',
#     'url': 'http://twitter.com/search?q=%23SaturdayMotivation',
#     'promoted_content': None,
#     'query': '%23SaturdayMotivation',
#     'tweet_volume': None},
#    {'name': '#MaineCarloOnEB',
#     'url': 'http://twitter.com/search?q=%23MaineCarloOnEB',
#     'promoted_content': None,
#     'query': '%23MaineCarloOnEB',
#     'tweet_volume': 77198},
#    {'name': '#QuestionMark',
#     'url': 'http://twitter.com/search?q=%23QuestionMark',
#     'promoted_content': None,
#     'query': '%23QuestionMark',
#     'tweet_volume': None}],
#   'as_of': '2019-10-12T05:13:06Z',
#   'created_at': '2019-10-12T05:09:06Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys())) 
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#NLCS', 'url': 'http://twitter.com/search?q=%23NLCS', 'promoted_content': None, 'query': '%23NLCS', 'tweet_volume': 19961}, {'name': 'Shep Smith', 'url': 'http://twitter.com/search?q=%22Shep+Smith%22', 'promoted_content': None, 'query': '%22Shep+Smith%22', 'tweet_volume': 118020}, {'name': '#NationalComingOutDay', 'url': 'http://twitter.com/search?q=%23NationalComingOutDay', 'promoted_content': None, 'query': '%23NationalComingOutDay', 'tweet_volume': 147535}, {'name': 'El Camino', 'url': 'http://twitter.com/search?q=%22El+Camino%22', 'promoted_content': None, 'query': '%22El+Camino%22', 'tweet_volume': 125359}, {'name': '#SaddleridgeFire', 'url': 'http://twitter.com/search?q=%23SaddleridgeFire', 'promoted_content': None, 'query': '%23SaddleridgeFire', 'tweet_volume': 72318}, {'name': '#DayoftheGirl', 'url': 'http://twitter.com/search?q=%23DayoftheGirl', 'promoted_content': None, 'query': '%23DayoftheGirl', 'tweet_volume': 173364}, {'name': 'Harry Styles', 'url': 'http://twitter.com/search?q=%22Harry+Styles%22', 'promoted_content': None, 'query': '%22Harry+Styles%22', 'tweet_volume': 849173}, {'name': '#ImpeachAndRemove', 'url': 'http://twitter.com/search?q=%23ImpeachAndRemove', 'promoted_content': None, 'query': '%23ImpeachAndRemove', 'tweet_volume': 41736}, {'name': 'Jackie Brown', 'url': 'http://twitter.com/search?q=%22Jackie+Brown%22', 'promoted_content': None, 'query': '%22Jackie+Brown%22', 'tweet_volume': 12092}, {'name': 'Anibal Sanchez', 'url': 'http://twitter.com/search?q=%22Anibal+Sanchez%22', 'promoted_content': None, 'query': '%22Anibal+Sanchez%22', 'tweet_volume': 15879}, {'name': 'Bayley', 'url': 'http://twitter.com/search?q=Bayley', 'promoted_content': None, 'query': 'Bayley', 'tweet_volume': 31317}, {'name': 'Chocked', 'url': 'http://twitter.com/search?q=Chocked', 'promoted_content': None, 'query': 'Chocked', 'tweet_volume': 10769}, {'name': 'With Love 2', 'url': 'http://twitter.com/search?q=%22With+Love+2%22', 'promoted_content': None, 'query': '%22With+Love+2%22', 'tweet_volume': None}, {'name': 'Just a Theory', 'url': 'http://twitter.com/search?q=%22Just+a+Theory%22', 'promoted_content': None, 'query': '%22Just+a+Theory%22', 'tweet_volume': None}, {'name': 'Montez', 'url': 'http://twitter.com/search?q=Montez', 'promoted_content': None, 'query': 'Montez', 'tweet_volume': None}, {'name': 'Enos', 'url': 'http://twitter.com/search?q=Enos', 'promoted_content': None, 'query': 'Enos', 'tweet_volume': None}, {'name': 'Mikolas', 'url': 'http://twitter.com/search?q=Mikolas', 'promoted_content': None, 'query': 'Mikolas', 'tweet_volume': None}, {'name': 'Chixtape 5', 'url': 'http://twitter.com/search?q=%22Chixtape+5%22', 'promoted_content': None, 'query': '%22Chixtape+5%22', 'tweet_volume': None}, {'name': 'Like Mike', 'url': 'http://twitter.com/search?q=%22Like+Mike%22', 'promoted_content': None, 'query': '%22Like+Mike%22', 'tweet_volume': None}, {'name': 'End of 3rd', 'url': 'http://twitter.com/search?q=%22End+of+3rd%22', 'promoted_content': None, 'query': '%22End+of+3rd%22', 'tweet_volume': None}, {'name': 'Breeland', 'url': 'http://twitter.com/search?q=Breeland', 'promoted_content': None, 'query': 'Breeland', 'tweet_volume': None}, {'name': 'Buffs', 'url': 'http://twitter.com/search?q=Buffs', 'promoted_content': None, 'query': 'Buffs', 'tweet_volume': None}, {'name': 'no hitter', 'url': 'http://twitter.com/search?q=%22no+hitter%22', 'promoted_content': None, 'query': '%22no+hitter%22', 'tweet_volume': None}, {'name': 'daniel hudson', 'url': 'http://twitter.com/search?q=%22daniel+hudson%22', 'promoted_content': None, 'query': '%22daniel+hudson%22', 'tweet_volume': None}, {'name': 'Empire Records', 'url': 'http://twitter.com/search?q=%22Empire+Records%22', 'promoted_content': None, 'query': '%22Empire+Records%22', 'tweet_volume': None}, {'name': "where's rudy", 'url': 'http://twitter.com/search?q=%22where%27s+rudy%22', 'promoted_content': None, 'query': '%22where%27s+rudy%22', 'tweet_volume': None}, {'name' ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %% [markdown]
# The JSON module is mainly used to convert the python dictionary-like response above into a JSON string that can be written into a file.<br>
# Here we also use 1 indent to make the default result easier to read.

# %%
import json
trends_js = json.dumps(us_trends[:2], indent=1)
print(trends_js)
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "Robert Forster",
#     "url": "http://twitter.com/search?q=%22Robert+Forster%22",
#     "promoted_content": null,
#     "query": "%22Robert+Forster%22",
#     "tweet_volume": 22321
#    },
#    {
#     "name": "Anibal Sanchez",
#     "url": "http://twitter.com/search?q=%22Anibal+Sanchez%22",
#     "promoted_content": null,
#     "query": "%22Anibal+Sanchez%22",
#     "tweet_volume": 15879
#    },
#    {
#     "name": "#ShaneXJeffree",
#     "url": "http://twitter.com/search?q=%23ShaneXJeffree",
#     "promoted_content": null,
#     "query": "%23ShaneXJeffree",
#     "tweet_volume": 27380
#    },
#    {
#     "name": "#NLCS",
#     "url": "http://twitter.com/search?q=%23NLCS",
#     "promoted_content": null,
#     "query": "%23NLCS",
#     "tweet_volume": 19961
#    },
#    {
#     "name": "Bayley",
#     "url": "http://twitter.com/search?q=Bayley",
#     "promoted_content": null,
#     "query": "Bayley",
#     "tweet_volume": 31317
#    },
#    {
#     "name": "#WWEDraft",
#     "url": "http://twitter.com/search?q=%23WWEDraft",
#     "promoted_content": null,
#     "query": "%23WWEDraft",
#     "tweet_volume": 45828
#    },
#    {
#     "name": "Chocked",
#     "url": "http://twitter.com/search?q=Chocked",
#     "promoted_content": null,
#     "query": "Chocked",
#     "tweet_volume": 10769
#    },
#    {
#     "name": "#TheReadOnFuse",
#     "url": "http://twitter.com/search?q=%23TheReadOnFuse",
#     "promoted_content": null,
#     "query": "%23TheReadOnFuse",
#     "tweet_volume": null
#    },
#    {
#     "name": "#QuestionMark",
#     "url": "http://twitter.com/search?q=%23QuestionMark",
#     "promoted_content": null,
#     "query": "%23QuestionMark",
#     "tweet_volume": null
#    },
#    {
#     "name": "With Love 2",
#     "url": "http://twitter.com/search?q=%22With+Love+2%22",
#     "promoted_content": null,
#     "query": "%22With+Love+2%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Just a Theory",
#     "url": "http://twitter.com/search?q=%22Just+a+Theory%22",
#     "promoted_content": null,
#     "query": "%22Just+a+Theory%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Montez",
#     "url": "http://twitter.com/search?q=Montez",
#     "promoted_content": null,
#     "query": "Montez",
#     "tweet_volume": null
#    },
#    {
#     "name": "Enos",
#     "url": "http://twitter.com/search?q=Enos",
#     "promoted_content": null,
#     "query": "Enos",
#     "tweet_volume": null
#    },
#    {
#     "name": "Mikolas",
#     "url": "http://twitter.com/search?q=Mikolas",
#     "promoted_content": null,
#     "query": "Mikolas",
#     "tweet_volume": null
#    },
#    {
#     "name": "Chixtape 5",
#     "url": "http://twitter.com/search?q=%22Chixtape+5%22",
#     "promoted_content": null,
#     "query": "%22Chixtape+5%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Like Mike",
#     "url": "http://twitter.com/search?q=%22Like+Mike%22",
#     "promoted_content": null,
#     "query": "%22Like+Mike%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "End of 3rd",
#     "url": "http://twitter.com/search?q=%22End+of+3rd%22",
#     "promoted_content": null,
#     "query": "%22End+of+3rd%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Breeland",
#     "url": "http://twitter.com/search?q=Breeland",
#     "promoted_content": null,
#     "query": "Breeland",
#     "tweet_volume": null
#    },
#    {
#     "name": "Buffs",
#     "url": "http://twitter.com/search?q=Buffs",
#     "promoted_content": null,
#     "query": "Buffs",
#     "tweet_volume": null
#    },
#    {
#     "name": "no hitter",
#     "url": "http://twitter.com/search?q=%22no+hitter%22",
#     "promoted_content": null,
#     "query": "%22no+hitter%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "daniel hudson",
#     "url": "http://twitter.com/search?q=%22daniel+hudson%22",
#     "promoted_content": null,
#     "query": "%22daniel+hudson%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Empire Records",
#     "url": "http://twitter.com/search?q=%22Empire+Records%22",
#     "promoted_content": null,
#     "query": "%22Empire+Records%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "where's rudy",
#     "url": "http://twitter.com/search?q=%22where%27s+rudy%22",
#     "promoted_content": null,
#     "query": "%22where%27s+rudy%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "The Descendants",
#     "url": "http://twitter.com/search?q=%22The+Descendants%22",
#     "promoted_content": null,
#     "query": "%22The+Descendants%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Bryce Perkins",
#     "url": "http://twitter.com/search?q=%22Bryce+Perkins%22",
#     "promoted_content": null,
#     "query": "%22Bryce+Perkins%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kevin McAleenan",
#     "url": "http://twitter.com/search?q=%22Kevin+McAleenan%22",
#     "promoted_content": null,
#     "query": "%22Kevin+McAleenan%22",
#     "tweet_volume": 39176
#    },
#    {
#     "name": "Gobert",
#     "url": "http://twitter.com/search?q=Gobert",
#     "promoted_content": null,
#     "query": "Gobert",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WSHvsSTL",
#     "url": "http://twitter.com/search?q=%23WSHvsSTL",
#     "promoted_content": null,
#     "query": "%23WSHvsSTL",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GhostNation",
#     "url": "http://twitter.com/search?q=%23GhostNation",
#     "promoted_content": null,
#     "query": "%23GhostNation",
#     "tweet_volume": null
#    },
#    {
#     "name": "#PFLPlayoffs",
#     "url": "http://twitter.com/search?q=%23PFLPlayoffs",
#     "promoted_content": null,
#     "query": "%23PFLPlayoffs",
#     "tweet_volume": null
#    },
#    {
#     "name": "#loveafterlockup",
#     "url": "http://twitter.com/search?q=%23loveafterlockup",
#     "promoted_content": null,
#     "query": "%23loveafterlockup",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BlueBloods",
#     "url": "http://twitter.com/search?q=%23BlueBloods",
#     "promoted_content": null,
#     "query": "%23BlueBloods",
#     "tweet_volume": null
#    },
#    {
#     "name": "#UVAvsMIA",
#     "url": "http://twitter.com/search?q=%23UVAvsMIA",
#     "promoted_content": null,
#     "query": "%23UVAvsMIA",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TrumpTaxDeductions",
#     "url": "http://twitter.com/search?q=%23TrumpTaxDeductions",
#     "promoted_content": null,
#     "query": "%23TrumpTaxDeductions",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LandmarkSongOrShow",
#     "url": "http://twitter.com/search?q=%23LandmarkSongOrShow",
#     "promoted_content": null,
#     "query": "%23LandmarkSongOrShow",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Dateline",
#     "url": "http://twitter.com/search?q=%23Dateline",
#     "promoted_content": null,
#     "query": "%23Dateline",
#     "tweet_volume": null
#    },
#    {
#     "name": "#wafbscores",
#     "url": "http://twitter.com/search?q=%23wafbscores",
#     "promoted_content": null,
#     "query": "%23wafbscores",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SorryChuckTodd",
#     "url": "http://twitter.com/search?q=%23SorryChuckTodd",
#     "promoted_content": null,
#     "query": "%23SorryChuckTodd",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CUvsORE",
#     "url": "http://twitter.com/search?q=%23CUvsORE",
#     "promoted_content": null,
#     "query": "%23CUvsORE",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BreakingBadAFilm",
#     "url": "http://twitter.com/search?q=%23BreakingBadAFilm",
#     "promoted_content": null,
#     "query": "%23BreakingBadAFilm",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CartoonCandies",
#     "url": "http://twitter.com/search?q=%23CartoonCandies",
#     "promoted_content": null,
#     "query": "%23CartoonCandies",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FoundInTheTrunk",
#     "url": "http://twitter.com/search?q=%23FoundInTheTrunk",
#     "promoted_content": null,
#     "query": "%23FoundInTheTrunk",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ShepardSmith",
#     "url": "http://twitter.com/search?q=%23ShepardSmith",
#     "promoted_content": null,
#     "query": "%23ShepardSmith",
#     "tweet_volume": null
#    },
#    {
#     "name": "#iahsfb",
#     "url": "http://twitter.com/search?q=%23iahsfb",
#     "promoted_content": null,
#     "query": "%23iahsfb",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BMovieManiacs",
#     "url": "http://twitter.com/search?q=%23BMovieManiacs",
#     "promoted_content": null,
#     "query": "%23BMovieManiacs",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheU",
#     "url": "http://twitter.com/search?q=%23TheU",
#     "promoted_content": null,
#     "query": "%23TheU",
#     "tweet_volume": null
#    },
#    {
#     "name": "#fridaynight",
#     "url": "http://twitter.com/search?q=%23fridaynight",
#     "promoted_content": null,
#     "query": "%23fridaynight",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SignsYouAreSexy",
#     "url": "http://twitter.com/search?q=%23SignsYouAreSexy",
#     "promoted_content": null,
#     "query": "%23SignsYouAreSexy",
#     "tweet_volume": null
#    },
#    {
#     "name": "#realtime",
#     "url": "http://twitter.com/search?q=%23realtime",
#     "promoted_content": null,
#     "query": "%23realtime",
#     "tweet_volume": null
#    },
#    {
#     "name": "#wisfb",
#     "url": "http://twitter.com/search?q=%23wisfb",
#     "promoted_content": null,
#     "query": "%23wisfb",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2019-10-12T05:13:07Z",
#   "created_at": "2019-10-12T05:09:06Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %%
type(trends_js)
# Out:
# str

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
# get trend['name'] from each element (dict) of world_trends[0]['trends']:
# [{'name':  ,'url':  ,'promoted_content':   ,'query':  ,'tweet_volume':   }, {}...]
# create a set: set = ([  ])

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
trends_set['world']
# Out:
# {'#BigilTrailerDay',
#  '#Eliud159',
#  '#MaineCarloOnEB',
#  '#PVLCollegiateConference2019',
#  '#PrayForJapan',
#  '#ProvaDeFogo',
#  '#QuestionMark',
#  '#SaturdayMotivation',
#  '#ShaneXJeffree',
#  '#TeamNeilEnPremiosTelehit',
#  '#TheReadOnFuse',
#  '#WWEDraft',
#  '#cumartesi',
#  '#اليوم_العالمي_للرسايل',
#  '#كلمه_وقولها_للحب',
#  '#台風19',
#  '#台風だけど出社させた企業',
#  '#台風怖すぎるから会いたい人たち',
#  '#激獣神祭',
#  'Anibal Sanchez',
#  'Bayley',
#  'Chocked',
#  'Juanfer',
#  'Ralf',
#  'Robert Forster',
#  'Ryan Zimmerman',
#  'うんこ10連ガチャ',
#  'ほん怖',
#  'アナザーディエンド',
#  'エリアメール',
#  'カエサル',
#  'ハイキュー',
#  'ピーク',
#  'プロミ',
#  'ライブカメラ',
#  '多摩川',
#  '暴風域',
#  '氾濫危険水位',
#  '江戸川区',
#  '無事帰宅',
#  '緊急速報',
#  '警戒レベル4',
#  '避難勧告',
#  '避難場所',
#  '避難所',
#  '避難指示',
#  '避難準備',
#  '避難警報',
#  '雨と風',
#  '雨漏り'}

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# プロミ,#ProvaDeFogo,避難指示,避難警報,#台風だけど出社させた企業,避難勧告,エリアメール,#BigilTrailerDay,#اليوم_العالمي_للرسايل,ほん怖,#MaineCarloOnEB,無事帰宅,Ryan Zimmerman,Juanfer,#ShaneXJeffree,#激獣神祭,ライブカメラ,雨漏り,#PrayForJapan,#台風19,多摩川,アナザーディエンド,#cumartesi,#台風怖すぎるから会いたい人たち,うんこ10連ガチャ,緊急速報,カエサル,Bayley,Chocked,ハイキュー,氾濫危険水位,Ralf,暴風域,#TheReadOnFuse,雨と風,避難準備,#SaturdayMotivation,#كلمه_وقولها_للحب,Robert Forster,避難場所,#PVLCollegiateConference2019,#TeamNeilEnPremiosTelehit,#QuestionMark,避難所,#Eliud159,警戒レベル4,江戸川区,#WWEDraft,Anibal Sanchez,ピーク
# ('----------', 'us')
# Just a Theory,#loveafterlockup,Chixtape 5,Bryce Perkins,#LandmarkSongOrShow,#PFLPlayoffs,#BreakingBadAFilm,#CartoonCandies,#fridaynight,#wisfb,Kevin McAleenan,End of 3rd,#ShaneXJeffree,#UVAvsMIA,With Love 2,Like Mike,where's rudy,Mikolas,Montez,#wafbscores,#ShepardSmith,#TrumpTaxDeductions,#CUvsORE,no hitter,#Dateline,Bayley,Chocked,#GhostNation,#BMovieManiacs,#TheReadOnFuse,#NLCS,#TheU,Enos,#FoundInTheTrunk,#SorryChuckTodd,Gobert,The Descendants,Robert Forster,#iahsfb,Breeland,#QuestionMark,#BlueBloods,daniel hudson,Buffs,#WWEDraft,#WSHvsSTL,#SignsYouAreSexy,#realtime,Anibal Sanchez,Empire Records
# ('----------', 'san diego')
# Just a Theory,#loveafterlockup,Chixtape 5,#LandmarkSongOrShow,#NationalComingOutDay,#PFLPlayoffs,#BreakingBadAFilm,#CartoonCandies,#fridaynight,End of 3rd,#ShaneXJeffree,#UVAvsMIA,With Love 2,Like Mike,where's rudy,Mikolas,Montez,#wafbscores,#TrumpTaxDeductions,#CUvsORE,El Camino,no hitter,#Dateline,#ImpeachAndRemove,Bayley,Chocked,#GhostNation,Jackie Brown,#BMovieManiacs,#TheReadOnFuse,#NLCS,#TheU,Enos,#DayoftheGirl,#SaddleridgeFire,#FoundInTheTrunk,#SorryChuckTodd,Harry Styles,Shep Smith,#iahsfb,Breeland,#QuestionMark,#BlueBloods,daniel hudson,Buffs,#WWEDraft,#WSHvsSTL,#SignsYouAreSexy,Anibal Sanchez,Empire Records

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#ShaneXJeffree', 'Bayley', 'Chocked', 'Robert Forster', '#QuestionMark', '#TheReadOnFuse', '#WWEDraft', 'Anibal Sanchez'}
# ('==========', 'intersection of us and san-diego')
# {'Just a Theory', '#loveafterlockup', 'Chixtape 5', '#LandmarkSongOrShow', '#PFLPlayoffs', '#fridaynight', '#CartoonCandies', '#BreakingBadAFilm', 'End of 3rd', '#ShaneXJeffree', '#UVAvsMIA', 'With Love 2', 'Like Mike', "where's rudy", 'Mikolas', 'Montez', '#wafbscores', '#TrumpTaxDeductions', 'no hitter', '#Dateline', 'Bayley', 'Chocked', '#GhostNation', '#BMovieManiacs', '#TheReadOnFuse', '#NLCS', '#TheU', 'Enos', '#FoundInTheTrunk', '#SorryChuckTodd', '#iahsfb', 'Breeland', '#QuestionMark', '#BlueBloods', 'Empire Records', 'daniel hudson', 'Buffs', '#WWEDraft', '#WSHvsSTL', '#SignsYouAreSexy', 'Anibal Sanchez', '#CUvsORE'}

# %%
type (trends_set['world'])
# Out:
# set

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %% [markdown]
# search.tweets( )<br>
# q: search query of 500 characters maximum<br>
# count: The number of tweets to return per page, up to a maximum of 100.

# %%
q = '#MTVAwards'  # topic

number = 100 # most recent

# See https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses'] # [{'created_at':  ,'text':  ,... }, { }...]

# %%
type (search_results) # dict-like
# Out:
# twitter.api.TwitterDictResponse

# %%
search_results.keys()
# Out:
# dict_keys(['statuses', 'search_metadata'])

# %%
len(statuses)
# Out:
# 98

# %%
print(statuses) # twitters that we searched
# Out:
# [{'created_at': 'Fri Oct 11 10:32:10 +0000 2019', 'id': 1182604798924906496, 'id_str': '1182604798924906496', 'text': 'RT @MTVAwards: 😱MOST FRIGHTENED PERFORMANCE GOES TO....😱\n\n#SandraBullock in "Bird Box" #MTVAwards https://t.co/P2qNbSfZBQ', 'truncated': False, 'entities': {'hashtags': [{'text': 'SandraBullock', 'indices': [58, 72]}, {'text': 'MTVAwards', 'indices': [87, 97]}], 'symbols': [], 'user_mentions': [{'screen_name': 'MTVAwards', 'name': 'Movie & TV Awards', 'id': 834116685577740290, 'id_str': '834116685577740290', 'indices': [3, 13]}], 'urls': [], 'media': [{'id': 1140787812209266689, 'id_str': '1140787812209266689', 'indices': [98, 121], 'media_url': 'http://pbs.twimg.com/media/D9TknldU4AEy2OY.jpg', 'media_url_https': 'https://pbs.twimg.com/media/D9TknldU4AEy2OY.jpg', 'url': 'https://t.co/P2qNbSfZBQ', 'display_url': 'pic.twitter.com/P2qNbSfZBQ', 'expanded_url': 'https://twitter.com/MTVAwards/status/1140788314238148609/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 720, 'h': 720, 'resize': 'fit'}, 'large': {'w': 720, 'h': 720, 'resize': 'fit'}}, 'source_status_id': 1140788314238148609, 'source_status_id_str': '1140788314238148609', 'source_user_id': 834116685577740290, 'source_user_id_str': '834116685577740290'}]}, 'extended_entities': {'media': [{'id': 1140787812209266689, 'id_str': '1140787812209266689', 'indices': [98, 121], 'media_url': 'http://pbs.twimg.com/media/D9TknldU4AEy2OY.jpg', 'media_url_https': 'https://pbs.twimg.com/media/D9TknldU4AEy2OY.jpg', 'url': 'https://t.co/P2qNbSfZBQ', 'display_url': 'pic.twitter.com/P2qNbSfZBQ', 'expanded_url': 'https://twitter.com/MTVAwards/status/1140788314238148609/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 680, 'resize': 'fit'}, 'medium': {'w': 720, 'h': 720, 'resize': 'fit'}, 'large': {'w': 720, 'h': 720, 'resize': 'fit'}}, 'source_status_id': 1140788314238148609, 'source_status_id_str': '1140788314238148609', 'source_user_id': 834116685577740290, 'source_user_id_str': '834116685577740290', 'video_info': {'aspect_ratio': [1, 1], 'duration_millis': 4972, 'variants': [{'bitrate': 1280000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1140787812209266689/vid/720x720/DNO_bYHpo4Z-iiew.mp4?tag=13'}, {'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/amplify_video/1140787812209266689/pl/fC8O7rOP747xrn-h.m3u8?tag=13'}, {'bitrate': 432000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1140787812209266689/vid/320x320/hG8iGunkJOUA3PKh.mp4?tag=13'}, {'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1140787812209266689/vid/480x480/6tgqOofWVCukU4r3.mp4?tag=13'}]}, 'additional_media_info': {'title': '', 'description': '', 'embeddable': True, 'monetizable': False, 'source_user': {'id': 834116685577740290, 'id_str': '834116685577740290', 'name': 'Movie & TV Awards', 'screen_name': 'MTVAwards', 'location': 'Los Angeles, CA', 'description': "I'll bring the popcorn. 🍿 #MTVAwards", 'url': 'https://t.co/WDnzRI0LPX', 'entities': {'url': {'urls': [{'url': 'https://t.co/WDnzRI0LPX', 'expanded_url': 'http://mtvawards.mtv.com', 'display_url': 'mtvawards.mtv.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 34306, 'friends_count': 9883, 'listed_count': 171, 'created_at': 'Tue Feb 21 19:04:49 +0000 2017', 'favourites_count': 4178, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 3774, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_backgroun ...

# %% [markdown]
# Twitter often returns duplicate results (for example: people retweet the same tweet so the message would be the same), we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses: # s: dict
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 69

# %%
[s['text'] for s in search_results['statuses']] # s: dict
# Out:
# ['RT @MTVAwards: 😱MOST FRIGHTENED PERFORMANCE GOES TO....😱\n\n#SandraBullock in "Bird Box" #MTVAwards https://t.co/P2qNbSfZBQ',
#  'RT @MTVAwards: "Family is what you fight for. Family is what you protect." - #SandraBullock ❤️\n\n#MTVAwards',
#  'RT @MTV: Sandra Bullock takes home the golden popcorn for her Most Frightened Performance in #BirdBox! #MTVAwards https://t.co/YJ3R6exUkc',
#  'RT @sanbullockdaily: #SandraBullock just took home the Golden Popcorn for Most Frightened Performance at the #MTVAwards for her role in #Ne…',
#  'RT @theblackpanther: Congratulations to @ChadwickBoseman for winning tonight’s @MTV Movie Award for “Best Performance in a Movie” as T’Chal…',
#  'RT @theblackpanther: “@TheBlackPanther” has won “Best Movie” at the @MTV Awards! Thank you to all of the fans for your support. #WakandaFor…',
#  'RT @Variety: #StrangerThings @noah_schnapp wants to meet @Zendaya: "I love her" #MTVAwards https://t.co/WUK5j3LLqV https://t.co/SK2bIPNmWQ',
#  'RT @MTVAwards: NEVER FORGET that @xtina, @LilKim, @MYAPLANET9, and @Pink made history with "Lady Marmalade" at the #MTVAwards 💖🎀\n\nTHE INFLU…',
#  'https://t.co/hgYWUEoLyb @pearljam pearljam_forever @wk_editor @pearljamholland @pearljam_daily #pearljam #mtv… https://t.co/4p2QD2h61E',
#  'RT @JackGrazerFr: 🎥 || #MTVAwards https://t.co/3QgdjLmA2R',
#  "RT @captainmarvel: Congratulations to @BrieLarson and @Gemma_Chan for winning “Best Fight” in Marvel Studios' #CaptainMarvel at the @MTVAwa…",
#  'RT @MTV: YES! Girl Power!! @brielarson #MTVAwards https://t.co/QHBKbpNJe0',
#  '#betawards #mtvawards #grammys Hope y’all mf getting prepared for the storm that’s about to arrive 🗣😤💯🎵☝🏾 https://t.co/NFMYjWNZhe',
#  "RT @captainmarvel: Congratulations to @BrieLarson and @Gemma_Chan for winning “Best Fight” in Marvel Studios' #CaptainMarvel at the @MTVAwa…",
#  'RT @G_R_IND: @iamkinglos \nLink in bio\n🏃 |Culture Guardians | \nStream/Subscribe/Services.\n*\n*\n#tidal #revolt #massappeal #thisis50 #complex…',
#  '@iamkinglos \nLink in bio\n🏃 |Culture Guardians | \nStream/Subscribe/Services.\n*\n*\n#tidal #revolt #massappeal… https://t.co/RqpEkW0Zkd',
#  'RT @MTVAwards: NEVER FORGET that @xtina, @LilKim, @MYAPLANET9, and @Pink made history with "Lady Marmalade" at the #MTVAwards 💖🎀\n\nTHE INFLU…',
#  'RT @Dream__Payne: But why Ray J hat doing what my 🍆 can do when it git hard 🤔  #MTVAwards https://t.co/l83HuGdZOH',
#  'RT @Dream__Payne: But why Ray J hat doing what my 🍆 can do when it git hard 🤔  #MTVAwards https://t.co/l83HuGdZOH',
#  'RT @G_R_IND: @roddyricch "BIG STEPPER"\nLink in bio\n🏃 |Culture Guardians | \nStream/Subscribe/Services.\n*\n*\n#tidal #revolt #massappeal #thisi…',
#  '@roddyricch "BIG STEPPER"\nLink in bio\n🏃 |Culture Guardians | \nStream/Subscribe/Services.\n*\n*\n#tidal #revolt… https://t.co/AnwDWEkkw1',
#  'I’m sick of artist not showing up to the #betawards but will be front Roll at the #MTVawards. If you don’t show up.… https://t.co/dUhdAncc83',
#  "RT @MTVAwards: THREAD: While we count down to Halloween, let's look back at some of the #MTVAwards winners of MOST FRIGHTENED PERFORMANCE 😱…",
#  'RT @MTVAwards: NOTHING BUT RESPECT FOR THE BEST HERO @RobertDowneyJr \n\n#MTVAwards https://t.co/nviDPkRMk1',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @ladygaga: So happy that #GagaFiveFootTwo won Best Music Documentary at the #MTVAwards! Thank u Little Monsters &amp; @MTV!! 😘 https://t.co/…',
#  'RT @weeklygaga: Have you voted today #LittleMonsters Remember you can vote daily for #ladygaga‘s “Gaga: Five Foot Two” for “Best Music Docu…',
#  "RT @MTV: @ladygaga congrats!!! you've been nominated at the 2018 #mtvawards and can vote now at https://t.co/B6c16HKCG5 🌈 https://t.co/HQec…",
#  'RT @getFANDOM: Chris Pratt with all of the wisdom #MTVAwards https://t.co/eu5cXU7WcQ',
#  "RT @MTVAwards: THREAD: While we count down to Halloween, let's look back at some of the #MTVAwards winners of MOST FRIGHTENED PERFORMANCE 😱…",
#  "RT @MTVAwards: THREAD: While we count down to Halloween, let's look back at some of the #MTVAwards winners of MOST FRIGHTENED PERFORMANCE 😱…",
#  "RT @MTVAwards: THREAD: While we count down to Halloween, let's look back at some of the #MTVAwards winners of MOST FRIGHTENED PERFORMANCE 😱…",
#  "THREAD: While we count down to Halloween, let's look back at some of the #MTVAwards winners of MOST FRIGHTENED PERFORMANCE 😱🎃💀😈👻",
#  'RT @MTVteenwolf: 🚨 ALERT 🚨 The #TeenWolf cast at the #MTVAwards over years will always be CUTE AS HECK! Catch the show Monday, June 17th at…',
#  'RT @MTVteenwolf: ✨ me and my pack watching the #MTVAwards tonight at 9/8c ✨ https://t.co/ERQpzN9zWt',
#  'RT @MTVAwards: Throwback to the queen of literally everything @ParisHilton blessing us at the #MTVAwards 👑💄💅 \n\n#TBT https://t.co/HWpH2SB4vq',
#  "RT @MTV: The Losers' Club? More like the WINNERS CLUB ☺️☺️The cast of #ITMovie wins Best On-Screen Team at the #MTVAwards https://t.co/lq5u…",
#  'RT @MTVteenwolf: ✨ me and my pack watching the #MTVAwards tonight at 9/8c ✨ https://t.co/ERQpzN9zWt',
#  'RT @MTVAwards: Killer on the carpet, killer in the ring. @BeckyLynchWWE 👠🥊 \n\nLess than an hour until the #MTVAwards ❗️9p on @MTV 🙌 https://…',
#  'RT @G_R_IND: @cassidy_larsiny vs #arsenal \nLink in bio\n🏃 |Culture Guardians | \nStream/Subscribe/Services.\n*\n*\n#tidal #revolt #massappeal #t…',
#  'RT @G_R_IND: @cassidy_larsiny vs #arsenal \nLink in bio\n🏃 |Culture Guardians | \nStream/Subscribe/Services.\n*\n*\n#tidal #revolt #massappeal #t…',
#  '@cassidy_larsiny vs #arsenal \nLink in bio\n🏃 |Culture Guardians | \nStream/Subscribe/Services.\n*\n*\n#tidal #revolt… https://t.co/mf3R8HmzxD',
#  'RT @MTVAwards: Annabelle came to haunt the #MTVAwards red carpet 😱\n\nEnjoy this exclusive clip from @annabellemovie….🎀🖤 #AnnabelleComesHome…',
#  'Recorded the biggest song of my career right here. Link to song in bio. Lets go get this grammy!!!🏆 #grammyawards… https://t.co/ieTAGN6YGc',
#  'RT @YARDENxSHOVAL: Vote and rt #MTVHottest to keep this babyboy and his hyungs at the top😊✊\n@BTS_twt #BTS #BTSARMY #Mtvmiaw2019 #MTVBRKPOPB…',
#  'Recorded the biggest song of my career right here. Link to song in bio. Lets go get this grammy!!!🏆 #grammyawards… https://t.co/yPRlbgyygD',
#  'Recorded the biggest song of my career right here. Link to song in bio. Lets go get this grammy!!!🏆 #grammyawards… https://t.co/TA5mPKkq2O',
#  'Recorded the biggest song of my career right here. Link to song in bio. Lets go get this grammy!!!🏆 #grammyawards… https://t.co/GmIQFmsAfO',
#  'Recorded the biggest song of my career right here. Link to song in bio. Lets go get this grammy!!!🏆 #grammyawards… https://t.co/qSZbB8gglQ',
#  'RT @MTV: My boys have arrived!! 😍🔥 @GatenM123 @FinnSkata @noah_schnapp\n\nCatch the @Stranger_Things cast at the #MTVAwards this Monday at 9p…',
#  'RT @MTV: Losers Club lookin’ reallllll dapper at the #MTVAwards ✨ Catch the @ITMovieOfficial cast tonight at 9/8c! | 🎥: Justin NB Francis h…',
#  "RT @MTV: The Losers' Club? More like the WINNERS CLUB ☺️☺️The cast of #ITMovie wins Best On-Screen Team at the #MTVAwards https://t.co/lq5u…",
#  "RT @MTV: Congrats to @lovesimonmovie's @notnickrob and @KeiynanLonsdale for winning Best Kiss at the #MTVAwards😘 https://t.co/olg7h8fxl9",
#  "RT @MTVteenwolf: Here's to hoping that the weather at this Monday's #MTVAwards isn't as London-like as it was for @daniel_sharman in 2013…",
#  'RT @SeriesBrasil: O prêmio de "Melhor Atuação Assustadora" foi para...\n\nSandra Bullock • Bird Box #MTVAwards https://t.co/a51Icbgqga',
#  'RT @GGadotBR: 📹 Gal Gadot e Sandra Bullock sendo fotografadas na sala de imprensa do #MTVAwards.\nVia Instagram Story da MTV.\n https://t.co/…',
#  'RT @MTV: Is it too late for Sandra Bullock to adopt me?! #MTVAwards https://t.co/Qx6sUB9Xbx',
#  'RT @sanbullockof: BOA NOITE FANDOM ATÉ O OSCAR KKKK #MTVAwards https://t.co/Ryhvz4sVeu',
#  'RT @etnow: Sandra Bullock reveals she made Bird Box for her kids and her family 😭 #MTVAwards https://t.co/8P4Uycd1GM',
#  'RT @MTVAwards: #SandraBullock dedicated her #MTVAward for Most Frightened Performance in "Bird Box" to her family 💖\n\n#MTVAwards https://t.c…',
#  "RT @MTV: The Losers' Club? More like the WINNERS CLUB ☺️☺️The cast of #ITMovie wins Best On-Screen Team at the #MTVAwards https://t.co/lq5u…",
#  "RT @MTV: The Losers' Club? More like the WINNERS CLUB ☺️☺️The cast of #ITMovie wins Best On-Screen Team at the #MTVAwards https://t.co/lq5u…",
#  'RT @steventeaster: Lawg Mon,\n#MTVAwards was n next Galaxy! #bigGirls Rule!\n Smothered in the  Dairy-air! whew!\n#Lizzo lawg have mercy!\n.@Po…',
#  'RT @CMBYNFilm: Congratulations to @RealChalamet on his \n@MTVAwards nomination for Best Performance in a Movie. Vote today: https://t.co/SVb…',
#  'Allow in To enter The world agenda hwaiting #AB6IX #Hwi #abnew #DAEHWI #BLINDFORLOVE #6IXENSE #6ixsense #leedaehwi… https://t.co/NDHor9cmzt',
#  'Allow in To enter The world agenda Come in #abnew #AB6IX #BLINDFORLOVE #6IXENSE #6ixsense #leedaehwi #AB6IX #Hwi… https://t.co/09kzI6jesR',
#  'RT @jaedenmartell: Catch us on the #MTVAwards tonight! https://t.co/5mBLkKT11x',
#  'RT @MTV: Losers Club lookin’ reallllll dapper at the #MTVAwards ✨ Catch the @ITMovieOfficial cast tonight at 9/8c! | 🎥: Justin NB Francis h…',
#  "RT @MTV: The Losers' Club? More like the WINNERS CLUB ☺️☺️The cast of #ITMovie wins Best On-Screen Team at the #MTVAwards https://t.co/lq5u…",
#  'RT @MTV: Congratulations to @ladygaga for winning Best Performance in a Movie for her role in @starisbornmovie! 🌟 #MTVAwards https://t.co/N…',
#  'RT @seewhatsnext: Congrats to our #MTVAwards noms!\n\nBEST MOVIE\nTo All The Boys \n\nBEST SHOW\n#BigMouth\n#HauntingOfHillHouse\n\nBEST MOVIE PERF.…',
#  'RT @MTV: Losers Club lookin’ reallllll dapper at the #MTVAwards ✨ Catch the @ITMovieOfficial cast tonight at 9/8c! | 🎥: Justin NB Francis h…',
#  "RT @MTV: The Losers' Club? More like the WINNERS CLUB ☺️☺️The cast of #ITMovie wins Best On-Screen Team at the #MTVAwards https://t.co/lq5u…",
#  '#Halloween post number 3 trillion:\nYOU KNOW YOU WANT IT. #robinthicke #mileycryus #wecantstopwewontstop #mtvawards… https://t.co/4whF4iK73Q',
#  "RT @Kaitiii: If Haley Lu Richardson had a Twitter, then she'd have to deal with me tweeting about how much I love her every single day. #MT…",
#  'RT @MTVteenwolf: ✨ me and my pack watching the #MTVAwards tonight at 9/8c ✨ https://t.co/ERQpzN9zWt',
#  'RT @MTVAwards: NEVER FORGET that @xtina, @LilKim, @MYAPLANET9, and @Pink made history with "Lady Marmalade" at the #MTVAwards 💖🎀\n\nTHE INFLU…',
#  'RT @MTV: "Kindness always wins!" Congrats to @danjlevy for Best Comedic Performance! #MTVAwards https://t.co/kcnjRRpv4J',
#  'RT @DailyRoss: [ULTRA HQ] [PHOTO] @RossLynch, @kiernanshipka, and @gtleatherwood on stage at the #MTVAwards #ChillingAdventuresofSabrina #C…',
#  'RT @MTV: Losers Club lookin’ reallllll dapper at the #MTVAwards ✨ Catch the @ITMovieOfficial cast tonight at 9/8c! | 🎥: Justin NB Francis h…',
#  'RT @midiaKSBR: Adicionamos mais de 300 fotos UHQ exclusivas da Kiernan Shipka no #MTVAwards em nossa galeria; confira: https://t.co/CLjEqSN…',
#  "RT @MTVAwards: ❤️@NickCannon's #MTVAwards acceptance speech always brings me so much JOY 🎉 https://t.co/srQxk6DbRA",
#  'RT @Lupita_Nyongo: Thank you @MTV for my Best Performance and Best Villain #UsMovie nominations, and for recognizing the film in the Best M…',
#  'RT @MTVAwards: NEVER FORGET that @xtina, @LilKim, @MYAPLANET9, and @Pink made history with "Lady Marmalade" at the #MTVAwards 💖🎀\n\nTHE INFLU…',
#  'RT @MTVAwards: NEVER FORGET that @xtina, @LilKim, @MYAPLANET9, and @Pink made history with "Lady Marmalade" at the #MTVAwards 💖🎀\n\nTHE INFLU…',
#  'RT @MTV: Losers Club lookin’ reallllll dapper at the #MTVAwards ✨ Catch the @ITMovieOfficial cast tonight at 9/8c! | 🎥: Justin NB Francis h…',
#  'RT @MTVAwards: NEVER FORGET that @xtina, @LilKim, @MYAPLANET9, and @Pink made history with "Lady Marmalade" at the #MTVAwards 💖🎀\n\nTHE INFLU…',
#  'RT @MTVAwards: NEVER FORGET that @xtina, @LilKim, @MYAPLANET9, and @Pink made history with "Lady Marmalade" at the #MTVAwards 💖🎀\n\nTHE INFLU…',
#  'RT @MTVAwards: NEVER FORGET that @xtina, @LilKim, @MYAPLANET9, and @Pink made history with "Lady Marmalade" at the #MTVAwards 💖🎀\n\nTHE INFLU…',
#  'RT @MTVAwards: NEVER FORGET that @xtina, @LilKim, @MYAPLANET9, and @Pink made history with "Lady Marmalade" at the #MTVAwards 💖🎀\n\nTHE INFLU…',
#  'RT @MTVAwards: NEVER FORGET that @xtina, @LilKim, @MYAPLANET9, and @Pink made history with "Lady Marmalade" at the #MTVAwards 💖🎀\n\nTHE INFLU…',
#  'RT @MTVAwards: NEVER FORGET that @xtina, @LilKim, @MYAPLANET9, and @Pink made history with "Lady Marmalade" at the #MTVAwards 💖🎀\n\nTHE INFLU…',
#  "❤️@NickCannon's #MTVAwards acceptance speech always brings me so much JOY 🎉 https://t.co/srQxk6DbRA",
#  'RT @MTV: So @bazzi had me feeling some type of way with this performance! #MTVAwards 🎤 https://t.co/uQvH8vWTZ8',
#  'RT @MTVAwards: Throwback to the queen of literally everything @ParisHilton blessing us at the #MTVAwards 👑💄💅 \n\n#TBT https://t.co/HWpH2SB4vq',
#  "RT @MTV: Congratulations to @RobertDowneyJr for winning Best Hero at this year's #MTVAwards! 💥 https://t.co/9GUcPeaIeh",
#  'RT @seewhatsnext: Congrats to our #MTVAwards noms!\n\nBEST MOVIE\nTo All The Boys \n\nBEST SHOW\n#BigMouth\n#HauntingOfHillHouse\n\nBEST MOVIE PERF.…',
#  "RT @StephMcMahon: Today is the last day to vote @WWERomanReigns for 'Best Real-Life Hero' at the @MTVAwards on June 17th! Vote now: https:/…"]

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Fri Oct 11 10:32:10 +0000 2019",
#  "id": 1182604798924906496,
#  "id_str": "1182604798924906496",
#  "text": "RT @MTVAwards: \ud83d\ude31MOST FRIGHTENED PERFORMANCE GOES TO....\ud83d\ude31\n\n#SandraBullock in \"Bird Box\" #MTVAwards https://t.co/P2qNbSfZBQ",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "SandraBullock",
#     "indices": [
#      58,
#      72
#     ]
#    },
#    {
#     "text": "MTVAwards",
#     "indices": [
#      87,
#      97
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "MTVAwards",
#     "name": "Movie & TV Awards",
#     "id": 834116685577740290,
#     "id_str": "834116685577740290",
#     "indices": [
#      3,
#      13
#     ]
#    }
#   ],
#   "urls": [],
#   "media": [
#    {
#     "id": 1140787812209266689,
#     "id_str": "1140787812209266689",
#     "indices": [
#      98,
#      121
#     ],
#     "media_url": "http://pbs.twimg.com/media/D9TknldU4AEy2OY.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/D9TknldU4AEy2OY.jpg",
#     "url": "https://t.co/P2qNbSfZBQ",
#     "display_url": "pic.twitter.com/P2qNbSfZBQ",
#     "expanded_url": "https://twitter.com/MTVAwards/status/1140788314238148609/video/1",
#     "type": "photo",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "small": {
#       "w": 680,
#       "h": 680,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 720,
#       "h": 720,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 720,
#       "h": 720,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 1140788314238148609,
#     "source_status_id_str": "1140788314238148609",
#     "source_user_id": 834116685577740290,
#     "source_user_id_str": "834116685577740290"
#    }
#   ]
#  },
#  "extended_entities": {
#   "media": [
#    {
#     "id": 1140787812209266689,
#     "id_str": "1140787812209266689",
#     "indices": [
#      98,
#      121
#     ],
#     "media_url": "http://pbs.twimg.com/media/D9TknldU4AEy2OY.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/D9TknldU4AEy2OY.jpg",
#     "url": "https://t.co/P2qNbSfZBQ",
#     "display_url": "pic.twitter.com/P2qNbSfZBQ",
#     "expanded_url": "https://twitter.com/MTVAwards/status/1140788314238148609/video/1",
#     "type": "video",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "small": {
#       "w": 680,
#       "h": 680,
#       "resize": "fit"
#      },
#      "medium": {
#       "w": 720,
#       "h": 720,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 720,
#       "h": 720,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 1140788314238148609,
#     "source_status_id_str": "1140788314238148609",
#     "source_user_id": 834116685577740290,
#     "source_user_id_str": "834116685577740290",
#     "video_info": {
#      "aspect_ratio": [
#       1,
#       1
#      ],
#      "duration_millis": 4972,
#      "variants": [
#       {
#        "bitrate": 1280000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/amplify_video/1140787812209266689/vid/720x720/DNO_bYHpo4Z-iiew.mp4?tag=13"
#       },
#       {
#        "content_type": "application/x-mpegURL",
#        "url": "https://video.twimg.com/amplify_video/1140787812209266689/pl/fC8O7rOP747xrn-h.m3u8?tag=13"
#       },
#       {
#        "bitrate": 432000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/amplify_video/1140787812209266689/vid/320x320/hG8iGunkJOUA3PKh.mp4?tag=13"
#       },
#       {
#        "bitrate": 832000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/amplify_video/1140787812209266689/vid/480x480/6tgqOofWVCukU4r3.mp4?tag=13"
#       }
#      ]
#     },
#     "additional_media_info": {
#      "title": "",
#      "description": "",
#      "embeddable": true,
#      "monetizable": false,
#      "source_user": {
#       "id": 834116685577740290,
#       "id_str": "834116685577740290",
#       "name": "Movie & TV Awards",
#       "screen_name": "MTVAwards",
#       "location": "Los Angeles, CA",
#       "description": "I'll bring the popcorn. \ud83c\udf7f #MTVAwards",
#       "url": "https://t.co/WDnzRI0LPX",
#       "entities": {
#        "url": {
#         "urls": [
#          {
#           "url": "https://t.co/WDnzRI0LPX",
#           "expanded_url": "http://mtvawards.mtv.com",
#           "display_url": "mtvawards.mtv.com",
#           "indices": [
#            0,
#            23
#           ]
#          }
#         ]
#        },
#        "description": {
#         "urls": []
#        }
#       },
#       "protected": false,
#       "followers_count": 34306,
#       "friends_count": 9883,
#       "listed_count": 171,
#       "created_at": "Tue Feb 21 19:04:49 +0000 2017",
#       "favourites_count": 4178,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": false,
#       "verified": true,
#       "statuses_count": 3774,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": false,
#       "profile_background_color": "000000",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#       "profile_background_tile": false,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1128375150821433345/GNg-UOVo_normal.png",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1128375150821433345/GNg-UOVo_normal.png",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/834116685577740290/1561572089",
#       "profile_link_color": "D4AF37",
#       "profile_sidebar_border_color": "000000",
#       "profile_sidebar_fill_color": "000000",
#       "profile_text_color": "000000",
#       "profile_use_background_image": false,
#       "has_extended_profile": true,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "translator_type": "none"
#      }
#     }
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 936593675563470849,
#   "id_str": "936593675563470849",
#   "name": "Ebtesam",
#   "screen_name": "Ebtesam00369622",
#   "location": "\u0627\u0644\u0639\u0627\u0635\u0645\u0647, \u062f\u0648\u0644\u0629 \u0627\u0644\u0643\u0648\u064a\u062a",
#   "description": "\u0627\u0646\u0627 \u0628\u0637\u0628\u0639\u064a \u0627\u0646\u0633\u0627\u0646 \u0623\u062d\u0628 \u0648\u0627\u062a\u0645\u0646\u064a \u0627\u0644\u0633\u0644\u0627\u0645 \u0627\u0644\u0639\u0627\u0644\u0645\u064a\u270c\ufe0f",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 3796,
#   "friends_count": 933,
#   "listed_count": 116,
#   "created_at": "Fri Dec 01 13:51:48 +0000 2017",
#   "favourites_count": 583809,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 471375,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/936594165646921729/dg2JYcFE_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/936594165646921729/dg2JYcFE_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/936593675563470849/1547837128",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Tue Jun 18 01:08:23 +0000 2019",
#   "id": 1140788314238148609,
#   "id_str": "1140788314238148609",
#   "text": "\ud83d\ude31MOST FRIGHTENED PERFORMANCE GOES TO....\ud83d\ude31\n\n#SandraBullock in \"Bird Box\" #MTVAwards https://t.co/P2qNbSfZBQ",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "SandraBullock",
#      "indices": [
#       43,
#       57
#      ]
#     },
#     {
#      "text": "MTVAwards",
#      "indices": [
#       72,
#       82
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [],
#    "media": [
#     {
#      "id": 1140787812209266689,
#      "id_str": "1140787812209266689",
#      "indices": [
#       83,
#       106
#      ],
#      "media_url": "http://pbs.twimg.com/media/D9TknldU4AEy2OY.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/D9TknldU4AEy2OY.jpg",
#      "url": "https://t.co/P2qNbSfZBQ",
#      "display_url": "pic.twitter.com/P2qNbSfZBQ",
#      "expanded_url": "https://twitter.com/MTVAwards/status/1140788314238148609/video/1",
#      "type": "photo",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "small": {
#        "w": 680,
#        "h": 680,
#        "resize": "fit"
#       },
#       "medium": {
#        "w": 720,
#        "h": 720,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 720,
#        "h": 720,
#        "resize": "fit"
#       }
#      }
#     }
#    ]
#   },
#   "extended_entities": {
#    "media": [
#     {
#      "id": 1140787812209266689,
#      "id_str": "1140787812209266689",
#      "indices": [
#       83,
#       106
#      ],
#      "media_url": "http://pbs.twimg.com/media/D9TknldU4AEy2OY.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/D9TknldU4AEy2OY.jpg",
#      "url": "https://t.co/P2qNbSfZBQ",
#      "display_url": "pic.twitter.com/P2qNbSfZBQ",
#      "expanded_url": "https://twitter.com/MTVAwards/status/1140788314238148609/video/1",
#      "type": "video",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "small": {
#        "w": 680,
#        "h": 680,
#        "resize": "fit"
#       },
#       "medium": {
#        "w": 720,
#        "h": 720,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 720,
#        "h": 720,
#        "resize": "fit"
#       }
#      },
#      "video_info": {
#       "aspect_ratio": [
#        1,
#        1
#       ],
#       "duration_millis": 4972,
#       "variants": [
#        {
#         "bitrate": 1280000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/amplify_video/1140787812209266689/vid/720x720/DNO_bYHpo4Z-iiew.mp4?tag=13"
#        },
#        {
#         "content_type": "application/x-mpegURL",
#         "url": "https://video.twimg.com/amplify_video/1140787812209266689/pl/fC8O7rOP747xrn-h.m3u8?tag=13"
#        },
#        {
#         "bitrate": 432000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/amplify_video/1140787812209266689/vid/320x320/hG8iGunkJOUA3PKh.mp4?tag=13"
#        },
#        {
#         "bitrate": 832000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/amplify_video/1140787812209266689/vid/480x480/6tgqOofWVCukU4r3.mp4?tag=13"
#        }
#       ]
#      },
#      "additional_media_info": {
#       "title": "",
#       "description": "",
#       "embeddable": true,
#       "monetizable": false
#      }
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"https://studio.twitter.com\" rel=\"nofollow\">Twitter Media Studio</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 834116685577740290,
#    "id_str": "834116685577740290",
#    "name": "Movie & TV Awards",
#    "screen_name": "MTVAwards",
#    "location": "Los Angeles, CA",
#    "description": "I'll bring the popcorn. \ud83c\udf7f #MTVAwards",
#    "url": "https://t.co/WDnzRI0LPX",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/WDnzRI0LPX",
#        "expanded_url": "http://mtvawards.mtv.com",
#        "display_url": "mtvawards.mtv.com",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 34306,
#    "friends_count": 9883,
#    "listed_count": 171,
#    "created_at": "Tue Feb 21 19:04:49 +0000 2017",
#    "favourites_count": 4178,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": true,
#    "statuses_count": 3774,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "000000",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1128375150821433345/GNg-UOVo_normal.png",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1128375150821433345/GNg-UOVo_normal.png",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/834116685577740290/1561572089",
#    "profile_link_color": "D4AF37",
#    "profile_sidebar_border_color": "000000",
#    "profile_sidebar_fill_color": "000000",
#    "profile_text_color": "000000",
#    "profile_use_background_image": false,
#    "has_extended_profile": true,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 171,
#   "favorite_count": 470,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 171,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "en"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0] # t: dict
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 171
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]
# Screen name is the username of the twitter account.
screen_names = [ user_mention['screen_name'] 
                 for status in statuses # status:{}
                     for user_mention in status['entities']['user_mentions'] ]  # like a hierarchy database

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ] # split extracted text into words

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @MTVteenwolf: \u2728 me and my pack watching the #MTVAwards tonight at 9/8c \u2728 https://t.co/ERQpzN9zWt",
#  "RT @CMBYNFilm: Congratulations to @RealChalamet on his \n@MTVAwards nomination for Best Performance in a Movie. Vote today: https://t.co/SVb\u2026",
#  "RT @MTVAwards: \ud83d\ude31MOST FRIGHTENED PERFORMANCE GOES TO....\ud83d\ude31\n\n#SandraBullock in \"Bird Box\" #MTVAwards https://t.co/P2qNbSfZBQ",
#  "RT @MTVAwards: \"Family is what you fight for. Family is what you protect.\" - #SandraBullock \u2764\ufe0f\n\n#MTVAwards",
#  "RT @MTV: Sandra Bullock takes home the golden popcorn for her Most Frightened Performance in #BirdBox! #MTVAwards https://t.co/YJ3R6exUkc"
# ]
# [
#  "MTVteenwolf",
#  "CMBYNFilm",
#  "RealChalamet",
#  "MTVAwards",
#  "MTVAwards"
# ]
# [
#  "MTVAwards",
#  "SandraBullock",
#  "MTVAwards",
#  "SandraBullock",
#  "MTVAwards"
# ]
# [
#  "RT",
#  "@MTVteenwolf:",
#  "\u2728",
#  "me",
#  "and"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print (type(c)) # a list of tuples
    print(c.most_common()[:10]) # top 10, a list of tuples
    print()
# Out:
# <class 'collections.Counter'>
# [('RT', 73), ('the', 70), ('#MTVAwards', 56), ('at', 47), ('to', 31), ('in', 29), ('of', 27), ('for', 23), ('and', 20), ('@MTV:', 19)]
#
# <class 'collections.Counter'>
# [('MTV', 23), ('MTVAwards', 20), ('MTVteenwolf', 6), ('xtina', 6), ('LilKim', 6), ('MYAPLANET9', 6), ('Pink', 6), ('G_R_IND', 4), ('ITMovieOfficial', 4), ('theblackpanther', 3)]
#
# <class 'collections.Counter'>
# [('MTVAwards', 59), ('tidal', 7), ('revolt', 7), ('ITMovie', 6), ('massappeal', 5), ('grammyawards', 5), ('SandraBullock', 4), ('mtvawards', 3), ('arsenal', 3), ('AB6IX', 3)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count")) # \n: write in a new line, {:^20}: format centered within 20 
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))  # k,v : name and count number, {:>6}: right align

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# RT                   |     53
# the                  |     46
# #MTVAwards           |     38
# in                   |     27
# to                   |     27
# at                   |     25
# for                  |     23
# of                   |     15
# @MTV:                |     13
# *                    |     12
#
#     Screen Name      | Count
# ****************************************
# MTV                  |     18
# MTVAwards            |     12
# theblackpanther      |      3
# G_R_IND              |      3
# ladygaga             |      3
# MTVteenwolf          |      3
# noah_schnapp         |      2
# brielarson           |      2
# iamKingLos           |      2
# RoddyRicch           |      2
#
#       Hashtag        | Count
# ****************************************
# MTVAwards            |     42
# tidal                |      6
# revolt               |      6
# grammyawards         |      5
# SandraBullock        |      4
# massappeal           |      4
# mtvawards            |      3
# AB6IX                |      3
# betawards            |      2
# arsenal              |      2

# %% [markdown]
# ## Example 9. Finding the most popular retweets (sort the status['retweet_count'])

# %% [markdown]
# Retweets always contain two Tweet objects. <br>
# The 'original' Tweet being Retweeted is provided in a "retweeted_status" object.

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'],  # the popularity of a twitter
             status['retweeted_status']['user']['screen_name'], #This is the original user name. General: status['entities']['user_mentions']
             # check https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/intro-to-tweet-json
             status['text'].replace("\n","\\"))  # str.replace(old, new), here it merges text to least lines
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status # ensure it's a retwitter, object structure is different
           ]

# %%
retweets[:2]
# Out:
# [(171,
#   'MTVAwards',
#   'RT @MTVAwards: 😱MOST FRIGHTENED PERFORMANCE GOES TO....😱\\\\#SandraBullock in "Bird Box" #MTVAwards https://t.co/P2qNbSfZBQ'),
#  (76,
#   'MTVAwards',
#   'RT @MTVAwards: "Family is what you fight for. Family is what you protect." - #SandraBullock ❤️\\\\#MTVAwards')]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
str_test = 'I love you,\n but I do not know how' 
print (str_test)
print (str_test.replace("\n","\\"))

print ('It\'s raining') # escape the second '
#print ('It's raining')
print ('\hello') # the escape sequence cannot be recognized
# Out:
# I love you,
#  but I do not know how
# I love you,\ but I do not know how
# It's raining
# \hello

# %% [markdown]
# Python uses **the backslash '\\' : 1. signals a special sequence or 2. as an escape sequence**; if the escape sequence isn’t recognized by Python’s parser, the backslash and subsequent character are included in the resulting string.<br>
# https://www.pitt.edu/~naraehan/python2/tutorial7.html

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print() # an empty line
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50])) # split the text of a Tweet (140 characters) into 3 lines with 50 characters each
        if len(text) > 50:
            print(row_template.format("", "", text[50:100])) # align the remained text to the next row
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10]) # sort retweets by the first variable: Count
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#  13893  |    getFANDOM    | RT @getFANDOM: Chris Pratt with all of the wisdom
#         |                 | #MTVAwards https://t.co/eu5cXU7WcQ
#  9307   |    ladygaga     | RT @ladygaga: So happy that #GagaFiveFootTwo won B
#         |                 | est Music Documentary at the #MTVAwards! Thank u L
#         |                 | ittle Monsters &amp; @MTV!! 😘 https://t.co/…
#  6588   |       MTV       | RT @MTV: YES! Girl Power!! @brielarson #MTVAwards
#         |                 | https://t.co/QHBKbpNJe0
#  5704   | theblackpanther | RT @theblackpanther: “@TheBlackPanther” has won “B
#         |                 | est Movie” at the @MTV Awards! Thank you to all of
#         |                 |  the fans for your support. #WakandaFor…
#  4529   |       MTV       | RT @MTV: Congratulations to @RobertDowneyJr for wi
#         |                 | nning Best Hero at this year's #MTVAwards! 💥 https
#         |                 | ://t.co/9GUcPeaIeh
#  4482   |       MTV       | RT @MTV: My queens @chloexhalle slayed their perfo
#         |                 | rmance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9
#  3492   |       MTV       | RT @MTV: Congrats to @lovesimonmovie's @notnickrob
#         |                 |  and @KeiynanLonsdale for winning Best Kiss at the
#         |                 |  #MTVAwards😘 https://t.co/olg7h8fxl9
#  3115   | theblackpanther | RT @theblackpanther: Congratulations to @ChadwickB
#         |                 | oseman for winning tonight’s @MTV Movie Award for
#         |                 | “Best Performance in a Movie” as T’Chal…
#  2592   |  captainmarvel  | RT @captainmarvel: Congratulations to @BrieLarson
#         |                 | and @Gemma_Chan for winning “Best Fight” in Marvel
#         |                 |  Studios' #CaptainMarvel at the @MTVAwa…
#  2549   |       MTV       | RT @MTV: The Losers' Club? More like the WINNERS C
#         |                 | LUB ☺️☺️The cast of #ITMovie wins Best On-Screen T
#         |                 | eam at the #MTVAwards https://t.co/lq5u…

# %% [markdown]
# RT @userName:<br>
# means it is a retweet message.
